# %%
import numpy as np
import pandas as pd

# Convert once — never parse CSV again
x_data = pd.read_csv('../datasets/input_data.csv', header=None, dtype=np.float32).values
y_data = pd.read_csv('../datasets/output_data.csv', header=None, dtype=np.float32).values
np.save('inputs.npy', x_data) 
np.save('outputs.npy', y_data)
